# %% [markdown]
# # 1.2.4 散度

# %% [markdown]
# 对于散度，我们除了要能求具体函数的散度，还要能画出其图像

# %% [markdown]
# ## 求具体函数的散度

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x^2 * i + y^2 * j + z * k
A = N.x**2 * N.i + N.y**2 * N.j + N.z * N.k

# 计算矢量场的散度
div_A = divergence(A)
#div_A = sp.simplify(div_A)

# 输出散度
print("矢量场的散度 (∇·A):")
print(div_A)
# Out:
# 矢量场的散度 (∇·A):
# 2*N.x + 2*N.y + 1

# %% [markdown]
# ### 矢量场散度的例子：从中心出发越来越大的矢量场

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x * i + y * j 
A = x * N.i + y * N.j

# 计算散度
div_A = divergence(A)
#div_A = sp.simplify(div_A)
print("计算其散度为：")
print(div_A)
# Out:
# 计算其散度为：
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rcParams
# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

print("其图像为：")
# 定义矢量场函数
def vector_field(x, y):
    # 这里定义矢量场 A = (A_x, A_y)，可以修改为你需要的函数
    A_x = x  # x 方向分量
    A_y = y   # y 方向分量
    return A_x, A_y
# 创建网格点
x = np.linspace(-5, 5, 5)
y = np.linspace(-5, 5, 5)
X, Y = np.meshgrid(x, y)

# 计算每个网格点的矢量场分量
A_x, A_y = vector_field(X, Y)
# 绘制矢量场
plt.figure(figsize=(8, 6))
plt.quiver(X, Y, A_x, A_y, angles='xy', scale_units='xy', scale=1, color='b')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X 轴')
plt.ylabel('Y 轴')
plt.title('二维矢量场图像')
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()
# Out:
# 其图像为：

# %% [markdown]
# ### 矢量场散度的例子：常数矢量场

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = 0 * i + 1 * j 
A = N.j
# 计算散度
div_A = divergence(A)
#div_A = sp.simplify(div_A)
print("计算其散度为：")
print(div_A)
# Out:
# 计算其散度为：
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rcParams
# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

print("其图像为：")
# 定义矢量场函数
def vector_field(x, y):
    # 这里定义矢量场 A = (A_x, A_y)，可以修改为你需要的函数
    A_x = 0  # x 方向分量
    A_y = 1   # y 方向分量
    return A_x, A_y
# 创建网格点
x = np.linspace(-5, 5, 6)
y = np.linspace(-5, 5, 6)
X, Y = np.meshgrid(x, y)

# 计算每个网格点的矢量场分量
A_x, A_y = vector_field(X, Y)
# 绘制矢量场
plt.figure(figsize=(8, 6))
plt.quiver(X, Y, A_x, A_y, angles='xy', scale_units='xy', scale=1, color='b')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X 轴')
plt.ylabel('Y 轴')
plt.title('二维矢量场图像')
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()
# Out:
# 其图像为：

# %% [markdown]
# ### 矢量场散度的例子：单个方向越来越大的矢量场

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = 0 * i + y * j 
A = y * N.j
# 计算散度
div_A = divergence( A)
#div_A = sp.simplify(div_A)
print("计算其散度为：")
print(div_A)
# Out:
# 计算其散度为：
# 1

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import rcParams
# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

print("其图像为：")
# 定义矢量场函数
def vector_field(x, y):
    # 这里定义矢量场 A = (A_x, A_y)，可以修改为你需要的函数
    A_x = np.zeros_like(y)  # x 方向分量
    A_y = y   # y 方向分量
    return A_x, A_y
# 创建网格点
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
X, Y = np.meshgrid(x, y)

# 计算每个网格点的矢量场分量
A_x, A_y = vector_field(X, Y)
# 绘制矢量场
plt.figure(figsize=(8, 6))
plt.quiver(X, Y, A_x, A_y, angles='xy', scale_units='xy', scale=1, color='b')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X 轴')
plt.ylabel('Y 轴')
plt.title('二维矢量场图像')
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()
# Out:
# 其图像为：

# %% [markdown]
# ### 习题1.16 画出矢量函数
# $$
#   \boldsymbol v = \frac{\hat{\boldsymbol r}}{r^2}
# $$
# 的草图，并计算出它的散度。
# 结果可能会使你惊讶……你可以解释它吗?

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x * i + y * j 
A = (x * N.i + y * N.j + z * N.k)/ ( (sp.sqrt(x**2 + y**2 + z**2)) ** 3)
# 计算散度
div_A = divergence(A)
div_A = sp.simplify(sp.expand(div_A))
print("计算其散度为：")
print(div_A)
# Out:
# 计算其散度为：
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from matplotlib import rcParams
# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

# 定义矢量场函数
def vector_field(x, y, z):
    A_x = X / (np.sqrt(X ** 2 + Y ** 2 + Z ** 2) ** 3)
    A_y = Y / (np.sqrt(X ** 2 + Y ** 2 + Z ** 2) ** 3)
    A_z = Z / (np.sqrt(X ** 2 + Y ** 2 + Z ** 2) ** 3)
    return A_x, A_y, A_z

# 创建 3D 网格点
x = np.linspace(-10, 10, 10)
y = np.linspace(-10, 10, 10)
z = np.linspace(-10, 10, 10)
X, Y, Z = np.meshgrid(x, y, z)

# 定义 3D 矢量场的分量
A_x, A_y, A_z = vector_field(X, Y, Z)

# 绘制 3D 矢量场
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, A_x, A_y, A_z, length=0.5, normalize=True, color='b')

ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
ax.set_zlim([-10, 10])
ax.set_xlabel('X 轴')
ax.set_ylabel('Y 轴')
ax.set_zlabel('Z 轴')
ax.set_title('三维矢量场图像')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the grid
x, y, z = np.meshgrid(np.arange(-10, 10, 2),
                      np.arange(-10, 10, 2),
                      np.arange(-10, 10, 2))

# Define the vector field components for a radial pattern
u = x
v = y
w = z

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(x, y, z, u, v, w, length=1, normalize=True, color='orange')

# Set plot limits for better visualization
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_zlim(-10, 10)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义二维网格 (XY 平面在 z=0)
x, y = np.meshgrid(np.linspace(-10, 10, 20), np.linspace(-10, 10, 20))
z = 0

# 定义二维径向矢量场的分量
u = x
v = y

# 计算矢量大小用于颜色映射
magnitude = np.sqrt(u**2 + v**2)

# 创建二维矢量场图
plt.figure(figsize=(8, 8))
plt.quiver(x, y, u, v, magnitude, cmap='plasma')
plt.colorbar(label='Magnitude')
plt.title('二维径向矢量场 (XY 平面)')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 求抽象向量场的散度

# %%
import sympy as sp
from sympy.vector import CoordSys3D, divergence
from sympy import Function

# 创建一个三维坐标系
N = CoordSys3D('N')

# 定义抽象的标量场 f(x, y, z) 和向量场 A(x, y, z)
x, y, z = N.x, N.y, N.z
Ax, Ay, Az = Function('Ax')(x, y, z), Function('Ay')(x, y, z), Function('Az')(x, y, z)
A = Ax*N.i + Ay*N.j + Az*N.k  # 抽象向量场 A

# 散度运算
div_A = divergence(A)  # 使用 & 运算符进行散度计算
print("\n散度 (∇·A):")
print(div_A)
# Out:
# 散度 (∇·A):
# Derivative(Ax(N.x, N.y, N.z), N.x) + Derivative(Ay(N.x, N.y, N.z), N.y) + Derivative(Az(N.x, N.y, N.z), N.z)

# %%
# 同时代入 Ax = x, Ay = y, Az = z
div_A_specific = div_A.subs({Ax: x, Ay: y, Az: z})

print("\n代入 Ax = x, Ay = y, Az = z 后的散度 (∇·A):")
print(sp.simplify(div_A_specific)
# Out:
# 代入 Ax = x, Ay = y, Az = z 后的散度 (∇·A):
# 3
