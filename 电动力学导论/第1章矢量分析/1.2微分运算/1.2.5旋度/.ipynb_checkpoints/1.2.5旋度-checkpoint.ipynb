# %% [markdown]
# # 1.2.5 旋度

# %% [markdown]
# ## 计算普通函数的旋度

# %%
import sympy as sp
from sympy.vector import CoordSys3D, curl

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x^2 * i + y^2 * j + z * k
A = -y**2 * N.i + x**2 * N.j + z * N.k

# 计算矢量场的散度
curl_A = curl(A)

# 输出散度
print("矢量场的旋度 (∇×A):")
print(curl_A)
# Out:
# 矢量场的旋度 (∇×A):
# (2*N.x + 2*N.y)*N.k

# %% [markdown]
# ### 矢量场散度的例子：绕着中心打转的矢量场

# %%
import sympy as sp
from sympy.vector import CoordSys3D, curl

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x^2 * i + y^2 * j + z * k
A = -y * N.i + x * N.j + 0 * N.k

# 计算矢量场的散度
curl_A = curl(A)

# 输出散度
print("矢量场的旋度 (∇×A):")
print(curl_A)
# Out:
# 矢量场的旋度 (∇×A):
# 2*N.k

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

# 定义矢量场函数
def vector_field(x, y):
    # 这里定义矢量场 A = (A_x, A_y)，可以修改为你需要的函数
    A_x = -y  # x 方向分量
    A_y = x   # y 方向分量
    return A_x, A_y

# 创建网格点
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
X, Y = np.meshgrid(x, y)

# 计算每个网格点的矢量场分量
A_x, A_y = vector_field(X, Y)

# 绘制矢量场
plt.figure(figsize=(8, 6))
plt.quiver(X, Y, A_x, A_y, angles='xy', scale_units='xy', scale=1, color='b')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X 轴')
plt.ylabel('Y 轴')
plt.title('二维矢量场图像')
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ### 矢量场散度的例子：跨越边界线反转方向的矢量场

# %%
import sympy as sp
from sympy.vector import CoordSys3D, curl

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义矢量场 A
# 假设 A = x^2 * i + y^2 * j + z * k
A = 0 * N.i + x * N.j + 0 * N.k

# 计算矢量场的散度
curl_A = curl(A)

# 输出散度
print("矢量场的旋度 (∇×A):")
print(curl_A)
# Out:
# 矢量场的旋度 (∇×A):
# N.k

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

# 设置字体，防止中文乱码
rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
rcParams['axes.unicode_minus'] = False    # 解决负号无法正常显示的问题

# 定义矢量场函数
def vector_field(x, y):
    # 这里定义矢量场 A = (A_x, A_y)，可以修改为你需要的函数
    A_x = np.zeros_like(y) # x 方向分量
    A_y = x   # y 方向分量
    return A_x, A_y

# 创建网格点
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
X, Y = np.meshgrid(x, y)

# 计算每个网格点的矢量场分量
A_x, A_y = vector_field(X, Y)

# 绘制矢量场
plt.figure(figsize=(8, 6))
plt.quiver(X, Y, A_x, A_y, angles='xy', scale_units='xy', scale=1, color='b')
plt.xlim(-6, 6)
plt.ylim(-6, 6)
plt.xlabel('X 轴')
plt.ylabel('Y 轴')
plt.title('二维矢量场图像')
plt.grid(True)
plt.gca().set_aspect('equal')
plt.show()

# %% [markdown]
# ## 计算抽象函数的旋度

# %%
import sympy as sp
from sympy.vector import CoordSys3D, curl
from sympy import Function

# 创建一个三维坐标系
N = CoordSys3D('N')
x, y, z = N.x, N.y, N.z

# 定义抽象的标量场 f(x, y, z) 和向量场 A(x, y, z)
x, y, z = N.x, N.y, N.z
f = Function('f')(x, y, z)  # 抽象标量场 f
Ax, Ay, Az = Function('Ax')(x, y, z), Function('Ay')(x, y, z), Function('Az')(x, y, z)
A = Ax*N.i + Ay*N.j + Az*N.k  # 抽象向量场 A

# 3. 旋度运算
curl_A = curl(A)  # 使用 ^ 运算符进行旋度计算
print("\n旋度 (∇×A):")
print(curl_A)
# Out:
# 旋度 (∇×A):
# (-Derivative(Ay(N.x, N.y, N.z), N.z) + Derivative(Az(N.x, N.y, N.z), N.y))*N.i + (Derivative(Ax(N.x, N.y, N.z), N.z) - Derivative(Az(N.x, N.y, N.z), N.x))*N.j + (-Derivative(Ax(N.x, N.y, N.z), N.y) + Derivative(Ay(N.x, N.y, N.z), N.x))*N.k
